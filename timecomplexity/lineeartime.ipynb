# %% [markdown]
# 1. Printing All Elements of a List

# %%
numbers=[10,20,30,40]
for num in numbers:
    print(num)

# %% [markdown]
# 2. Finding the Sum of All Elements

# %%
numbers=[10,20,300,40]
total = 0
for num in numbers:
    total += num
print(total)
