# %% [markdown]
# O(1) – Constant Time

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers[2])
# Out:
# 30

# %% [markdown]
# 1. Accessing a List Element

# %%
numbers=[10,20,30,40]
print(numbers[2])
# Out:
# 30

# %% [markdown]
# 2. Accessing a Dictionary Value

# %%
student = {  "name": "Anuradha",
           "age":20,
           "branch":"CSE"}
print(student["branch"])
# Out:
# CSE

# %% [markdown]
# 3. Updating a Variable

# %%
x=10
x=50
print(x)
# Out:
# 50

# %% [markdown]
# 4. Stack Push Operation

# %%
stack=[]
stack.append(10)
stack.append(20)
print(stack)
# Out:
# [10, 20]

# %% [markdown]
# 5. Stack Pop Operation

# %%
stack=[10,20,30]
removed = stack.pop()
print("Removed:",removed)
print("Stack:",stack)
# Out:
# Removed: 30
# Stack: [10, 20]

# %% [markdown]
# 6. Getting the Length of a List

# %%
numbers=(10,20,30)
print(len(numbers))
# Out:
# 3

# %% [markdown]
# 7. Accessing First Element of a Tuple

# %%
data = (100, 200, 300)
print(data[1])
# Out:
# 200
