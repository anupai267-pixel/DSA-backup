# %%
str1 = "listen"
str2 = "silent"

count1 = {}
count2 = {}

for ch in str1:
    count1[ch] = count1.get(ch, 0) + 1

for ch in str2:
    count2[ch] = count2.get(ch, 0) + 1

if count1 == count2:
    print("Anagram")
else:
    print("Not Anagram")
# Out:
# Anagram
