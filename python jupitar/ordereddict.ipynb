# %% [markdown]
# orderdedict

# %%
from collections import OrderedDict

od = OrderedDict()
od['apple'] = 1
od['banana'] = 2
od['cherry'] = 3

print(list(od.items()))
# Out:
# [('apple', 1), ('banana', 2), ('cherry', 3)]

# %% [markdown]
# OrderedDict vs Dict

# %%
from collections import OrderedDict

print("dict")
d = {}
d['a'] = 1
d['b'] = 2
d['c'] = 3
d['d'] = 4
for key, val in d.items():
    print(key, val)

print("ordered dict")
od = OrderedDict()
od['d'] = 4
od['b'] = 2
od['a'] = 1
od['c'] = 3
for key, val in od.items():
    print(key, val)
# Out:
# dict
# a 1
# b 2
# c 3
# d 4
# ordered dict
# d 4
# b 2
# a 1
# c 3

# %% [markdown]
# Key Features of OrderedDict

# %% [markdown]
# 1. Insertion order preservation

# %%
from collections import OrderedDict

d = {'a': 1, 'b': 2, 'c': 3}
for k, v in d.items():
    print(k, v)

print("OrderedDict:")
od = OrderedDict([('d', 4), ('b', 2), ('a', 1), ('c', 3)])
for k, v in od.items():
    print(k, v)
# Out:
# a 1
# b 2
# c 3
# OrderedDict:
# d 4
# b 2
# a 1
# c 3

# %% [markdown]
# 2. Changing value does not affect order

# %%
from collections import OrderedDict

od = OrderedDict([('a', 1), ('b', 2), ('c', 3), ('d', 4)])
od['c'] = 5  

for k, v in od.items():
    print(k, v)
# Out:
# a 1
# b 2
# c 5
# d 4

# %% [markdown]
# 3. Equality checks consider order

# %%
from collections import OrderedDict

od1 = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
od2 = OrderedDict([('c', 3), ('b', 2), ('a', 1)])
print(od1 == od2)
# Out:
# False

# %% [markdown]
# 4. Reversing an OrderedDict

# %%
from collections import OrderedDict

d1 = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
d2 = OrderedDict(reversed(list(d1.items())))

for k, v in d2.items():
    print(k, v)
# Out:
# c 3
# b 2
# a 1

# %% [markdown]
# 5. Pop last or first item

# %%
from collections import OrderedDict
d = OrderedDict([('a', 1), ('b', 2), ('c', 3)])

res = d.popitem(last=True)  # Remove last inserted item
print(res)
# Out:
# ('c', 3)

# %% [markdown]
# 6. Move Keys to Front or End

# %%
from collections import OrderedDict
d = OrderedDict([('a', 1), ('b', 2), ('c', 3)])
d.move_to_end('a')
print("Move 'a' to end:", d)
d.move_to_end('c', last=False)
print("Move 'c' to front:", d)
# Out:
# Move 'a' to end: OrderedDict({'b': 2, 'c': 3, 'a': 1})
# Move 'c' to front: OrderedDict({'c': 3, 'b': 2, 'a': 1})

# %% [markdown]
# 7. Deleting and re-inserting keys

# %%
from collections import OrderedDict
d=OrderedDict([('a',1),('b',2),('c',3)])
del d['b']
d['b']=10
print(d)
# Out:
# OrderedDict({'a': 1, 'c': 3, 'b': 10})
