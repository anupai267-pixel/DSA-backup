# %% [markdown]
# Inheritance

# %%
class Person:
    def __init__(self,name):
        self.name=name
    def display(self):
        print("Name:",self.name)
class Student(Person):
    def __init__(self,name,roll_no):
        super().__init__(name)  # Calls parent constructor
        self.roll_no=roll_no
    def display(self):          # Method overriding
        print("Name:",self.name)
        print("roll No:",self.roll_no)
s=Student("Anuradha",154)
s.display()
# Out:
# Name: Anuradha
# roll No: 154

# %% [markdown]
# Problem without super()    ----no output

# %%
class Animal:
    def __init__(self,name):
        self.name=name
        print("Animal constructor called")
class Dog(Animal):
    def __init__(self,name):
        self.name=name
d=Dog("Tommy")

# %% [markdown]
# with super():

# %%
class Animal:
    def __init__(self,name):
        self.name=name
        print("Animal constructor called")
class Dog(Animal):
    def __init__(self,name):
        super().__init__(name)
d=Dog("Tommy")
# Out:
# Animal constructor called
