# %% [markdown]
# Heap queue or heapq

# %%
import heapq
li = [25, 20, 15, 30, 40]
heapq.heapify(li)
print("Heap queue:", li)
# Out:
# Heap queue: [15, 20, 25, 30, 40]

# %% [markdown]
# Using Heap as a Max-Heap

# %%
import heapq
nums=[10,20,30,40,50]
max_heap=[-n for n in nums]
heapq.heapify(max_heap)
print("Largest element:",-max_heap[0])
# Out:
# Largest element: 50

# %% [markdown]
# Appending and Popping Elements

# %%
import heapq
h = [10, 20, 15, 30, 40]
heapq.heapify(h)
min = heapq.heappushpop(h, 5)
print(min)
print(h)
# Out:
# 5
# [10, 20, 15, 30, 40]

# %% [markdown]
# Finding Largest and Smallest Elements

# %%
import heapq
h=[10,20,30,40]
heapq.heapify(h)
maxi=heapq.nlargest(3,h)
print("3 largest elements:",maxi)
min=heapq.nsmallest(3,h)
print("3 smallest elements:",min)
# Out:
# 3 largest elements: [40, 30, 20]
# 3 smallest elements: [10, 20, 30]

# %% [markdown]
# Replace and Merge Operations

# %%
import heapq
h1=[10,20,40,60]
heapq.heapify(h1)
min=heapq.heapreplace(h1,5)
print(min)
print(h1)
h2=[2,4,6,8]
h3=list(heapq.merge(sorted(h1),sorted(h2)))
print("Merged heap:",h3)
# Out:
# 10
# [5, 20, 40, 60]
# Merged heap: [2, 4, 5, 6, 8, 20, 40, 60]
